# %%
from pycaret.regression import *
# import featuretools as fts
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
TRAIN_DIR = "../data/TRAIN.CSV"
TEST_DIR = "../data/TEST_FINAL.csv"

# %%
train = pd.read_csv(TRAIN_DIR)
test = pd.read_csv(TEST_DIR)

# %%
train_cols = ["Store_id","Store_Type","Location_Type","Region_Code","Holiday","Date","Discount","Sales"]

# %%
ids = train["Store_id"].unique().tolist()

# %%
model_id = ids[0]
store1 = train[train["Store_id"]==model_id]
print(store1.shape)
exp_reg101 = setup(data = store1[train_cols], target = 'Sales', session_id=123)
# Out:
# <style type="text/css">
# #T_a9c5c_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a9c5c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9c5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9c5c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a9c5c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a9c5c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9c5c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a9c5c_row1_col1" class="data row1 col1" >Sales</td>
#     </tr>
#     <tr>
#       <th id="T_a9c5c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9c5c_row2_col0" class="data row2 col0" >Original Data</td>
# ...

# %%
# exp_reg101 = setup(data = train[train_cols], target = 'Sales', session_id=123)

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_12a43_ th {
#   text-align: left;
# }
# ...

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_887c1_row10_col0, #T_887c1_row10_col1, #T_887c1_row10_col2, #T_887c1_row10_col3, #T_887c1_row10_col4, #T_887c1_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_887c1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_887c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_887c1_row0_col0" class="data row0 col0" >6558.9780</td>
#       <td id="T_887c1_row0_col1" class="data row0 col1" >81382448.0000</td>
#       <td id="T_887c1_row0_col2" class="data row0 col2" >9021.2217</td>
# ...

# %%
tuned_lr = tune_model(lr)
# Out:
# <style type="text/css">
# #T_23ff4_row10_col0, #T_23ff4_row10_col1, #T_23ff4_row10_col2, #T_23ff4_row10_col3, #T_23ff4_row10_col4, #T_23ff4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_23ff4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23ff4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23ff4_row0_col0" class="data row0 col0" >6558.9780</td>
#       <td id="T_23ff4_row0_col1" class="data row0 col1" >81382448.0000</td>
#       <td id="T_23ff4_row0_col2" class="data row0 col2" >9021.2217</td>
# ...

# %%
plot_model(tuned_lr)

# %%
plot_model(tuned_lr, plot = 'error')
# Out:
# /Users/GLanku/Nike/hackathon/venv/lib/python3.7/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/GLanku/Nike/hackathon/venv/lib/python3.7/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/GLanku/Nike/hackathon/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/GLanku/Nike/hackathon/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# ...
